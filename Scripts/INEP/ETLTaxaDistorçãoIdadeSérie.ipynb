# %% [markdown]
# # Definição de funções e imports necessários

# %%
import pandas as pd
import numpy as np
import json
import pymongo

# %% [markdown]
# ### Funções

# %%
def readXLSX (path):
    return pd.read_excel(path, index_col=None);

def openDataBaseMongoDB ():
    client = pymongo.MongoClient("mongodb://admin:CrIE1553@criedata-shard-00-00.urzuu.mongodb.net:27017,criedata-shard-00-01.urzuu.mongodb.net:27017,criedata-shard-00-02.urzuu.mongodb.net:27017/<dbname>?ssl=true&replicaSet=atlas-6db9id-shard-0&authSource=admin&retryWrites=true&w=majority");
    db = client.schoolData;
    return db.dataINEPSchools;

def deletingColumns (dataframe):
    columns = ["Região", 
               "UF", 
               "Código do Município", 
               "Nome do Município", 
               "Nome da Escola", 
               "Localização", 
               "Dependência Administrativa"];
    
    for column in columns:
        try:
            dataframe.pop(column)
        except:
            continue
    
def JSONstructure (data):    
    dataJSON = {"Taxa de distorção de idade-série por turma": 
                {
                "Última atualização": data["Ano"],
                "Ensino Fundamental 8 e 9 anos":
                    {
                        "Total": data["TotalF"],
                        "Anos Iniciais": data["Anos Iniciais"],
                        "Anos Finais": data["Anos Finais"],
                        "1 Ano": data["1° ano"],
                        "2 Ano": data["2° ano"],
                        "3 Ano": data["3° ano"],
                        "4 Ano": data["4° ano"],
                        "5 Ano": data["5° ano"],
                        "6 Ano": data["6° ano"],
                        "7 Ano": data["7° ano"],
                        "8 Ano": data["8° ano"],
                        "9 Ano": data["9° ano"]
                    },
                "Ensino Médio": 
                    {
                        "Total": data["TotalM"],
                        "1 série": data["1ª série"],
                        "2 série": data["2ª série"],
                        "3 série": data["3ª série"],
                        "4 série": data["4ª série"]
                    }
            }};

    return dataJSON;

def filterPelotas (dataframe):
    filter = dataframe["Nome do Município"] == "Pelotas"
    
    filterPelotas = dataframe[filter]
    filterPelotas.reset_index(drop=True, inplace=True)
    
    return filterPelotas

def insertIntoDB (dataframe, collection):
    for index, row in dataframe.iterrows():
        teste1 = JSONstructure(row);

        collection.update_one({"Código INEP": row["Código da Escola"]}, {"$set": teste1});

# %% [markdown]
# ### Conexão com o BD:

# %%
collection = openDataBaseMongoDB()

# %% [markdown]
# ### Extração dos dados

# %%
distortionRate = readXLSX(r'C:\Users\mbrug\Desktop\schoolDataCollectionPelotas\Datasets\INEP\TaxaDistorcaoIdadeSerie.xlsx')

# %%
distortionRate.head()
# Out:
#     Ano Região  UF  Código do Município      Nome do Município  \
# 0  2019  Norte  RO              1100015  Alta Floresta D'Oeste
# 1  2019  Norte  RO              1100015  Alta Floresta D'Oeste
# 2  2019  Norte  RO              1100015  Alta Floresta D'Oeste
# 3  2019  Norte  RO              1100015  Alta Floresta D'Oeste
# 4  2019  Norte  RO              1100015  Alta Floresta D'Oeste
#
#    Código da Escola               Nome da Escola Localização  \
# 0          11022558        EIEEF HAP BITT TUPARI       Rural
# 1          11024291          EMMEF 7 DE SETEMBRO       Rural
# 2          11024372              EMEIEF ANA NERY      Urbana
# 3          11024666         EMEIEF BOA ESPERANCA       Rural
# 4          11024682  EEEF EURIDICE LOPES PEDROSO      Urbana
#
#   Dependência Administrativa TotalF  ... 5° ano 6° ano 7° ano 8° ano 9° ano  \
# 0                   Estadual   14.3  ...      0     --     --     --     --
# 1                  Municipal      5  ...      0     --     --     --     --
# 2                  Municipal   13.7  ...   18.2      0   28.6   46.7     25
# 3                  Municipal   13.8  ...    9.1   21.2     20   19.2   38.9
# 4                   Estadual   15.6  ...   14.1     19   22.3   14.3     --
#
#   TotalM 1ª série 2ª série 3ª série 4ª série
# 0     --       --       --       --       --
# 1     --       --       --       --       --
# 2     --       --       --       --       --
# 3     --       --       --       --       --
# 4     --       --       --       --       --
#
# [5 rows x 26 columns]

# %%
distortionRate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132428 entries, 0 to 132427
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Ano                         132428 non-null  int64
#  1   Região                      132428 non-null  object
#  2   UF                          132428 non-null  object
#  3   Código do Município         132428 non-null  int64
#  4   Nome do Município           132428 non-null  object
#  5   Código da Escola            132428 non-null  int64
#  6   Nome da Escola              132428 non-null  object
#  7   Localização                 132428 non-null  object
#  8   Dependência Administrativa  132428 non-null  object
#  9   TotalF                      132428 non-null  object
#  10  Anos Iniciais               132428 non-null  object
#  11  Anos Finais                 132428 non-null  object
#  12  1° ano                      132428 non-null  object
#  13  2° ano                      132428 non-null  object
#  14  3° ano                      132428 non-null  object
#  15  4° ano                      132428 non-null  object
#  16  5° ano                      132428 non-null  object
#  17  6° ano                      132428 non-null  object
#  18  7° ano                      132428 non-null  object
#  19  8° ano                      132428 non-null  object
#  20  9° ano                      132428 non-null  object
#  21  TotalM                      132428 non-null  object
#  22  1ª série                    132428 non-null  object
#  23  2ª série                    132428 non-null  object
#  24  3ª série                    132428 non-null  object
#  25  4ª série                    132428 non-null  object
# dtypes: int64(3), object(23)
# memory usage: 26.3+ MB

# %% [markdown]
# ### Transformação dos dados

# %% [markdown]
# * Filtro das escolas de Pelotas

# %%
distortionRate_Pelotas = filterPelotas(distortionRate)

# %%
distortionRate_Pelotas.head()
# Out:
#     Ano Região  UF  Código do Município Nome do Município  Código da Escola  \
# 0  2019    Sul  RS              4314407           Pelotas          43000304
# 1  2019    Sul  RS              4314407           Pelotas          43003222
# 2  2019    Sul  RS              4314407           Pelotas          43012396
# 3  2019    Sul  RS              4314407           Pelotas          43065376
# 4  2019    Sul  RS              4314407           Pelotas          43100007
#
#                               Nome da Escola Localização  \
# 0                 COLEGIO TIRADENTES PELOTAS      Urbana
# 1                            EEF TRES VENDAS      Urbana
# 2  ESC EST ENS MED COLONIA DE PESCADORES Z 3       Rural
# 3                       EMEF WALDEMAR DENZER       Rural
# 4                            COLEGIO GONZAGA      Urbana
#
#   Dependência Administrativa TotalF  ... 5° ano 6° ano 7° ano 8° ano 9° ano  \
# 0                   Estadual     --  ...     --     --     --     --     --
# 1                    Privada    1.3  ...    1.3    2.7    1.6    4.1     --
# 2                   Estadual     --  ...     --     --     --     --     --
# 3                  Municipal     18  ...   14.3   31.3   38.9     25   18.8
# 4                    Privada      2  ...    0.9      0    1.3    5.6    4.4
#
#   TotalM 1ª série 2ª série 3ª série 4ª série
# 0   13.1      6.7     23.1      8.3       --
# 1     --       --       --       --       --
# 2   79.5     93.1       50     55.6       --
# 3     --       --       --       --       --
# 4    6.5       10      7.4      1.7       --
#
# [5 rows x 26 columns]

# %% [markdown]
# * Colunas desnecessárias

# %%
deletingColumns(distortionRate_Pelotas)

# %%
distortionRate_Pelotas.head()
# Out:
#     Ano  Código da Escola TotalF Anos Iniciais Anos Finais 1° ano 2° ano  \
# 0  2019          43000304     --            --          --     --     --
# 1  2019          43003222    1.3           0.5         2.9      0      0
# 2  2019          43012396     --            --          --     --     --
# 3  2019          43065376     18           3.1        29.1      0      0
# 4  2019          43100007      2           1.2           3      0    3.5
#
#   3° ano 4° ano 5° ano 6° ano 7° ano 8° ano 9° ano TotalM 1ª série 2ª série  \
# 0     --     --     --     --     --     --     --   13.1      6.7     23.1
# 1    1.1      0    1.3    2.7    1.6    4.1     --     --       --       --
# 2     --     --     --     --     --     --     --   79.5     93.1       50
# 3      0      0   14.3   31.3   38.9     25   18.8     --       --       --
# 4    0.8    1.1    0.9      0    1.3    5.6    4.4    6.5       10      7.4
#
#   3ª série 4ª série
# 0      8.3       --
# 1       --       --
# 2     55.6       --
# 3       --       --
# 4      1.7       --

# %% [markdown]
# ### Teste JSON

# %%
rowData = distortionRate_Pelotas.iloc[ 0 , : ]

# %%
JSONstructure(rowData)
# Out:
# {'Taxa de distorção de idade-série por turma': {'Última atualização': 2019,
#   'Ensino Fundamental 8 e 9 anos': {'Total': '--',
#    'Anos Iniciais': '--',
#    'Anos Finais': '--',
#    '1 Ano': '--',
#    '2 Ano': '--',
#    '3 Ano': '--',
#    '4 Ano': '--',
#    '5 Ano': '--',
#    '6 Ano': '--',
#    '7 Ano': '--',
#    '8 Ano': '--',
#    '9 Ano': '--'},
#   'Ensino Médio': {'Total': 13.1,
#    '1 série': 6.7,
#    '2 série': 23.1,
#    '3 série': 8.3,
#    '4 série': '--'}}}

# %% [markdown]
# ### Carregamento dos dados

# %% [markdown]
# * Inserindo no Banco de Dados (MongoDB)

# %%
insertIntoDB(distortionRate_Pelotas, collection)

# %%
collection.find_one({"Código INEP": 43000304})
