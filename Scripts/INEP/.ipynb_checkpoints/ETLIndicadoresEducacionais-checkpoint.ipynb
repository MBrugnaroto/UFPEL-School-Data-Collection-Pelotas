# %% [markdown]
# ### Definição de funções e imports necessários

# %%
import pandas as pd
import numpy as np
import json
import excel2json
from geopy.geocoders import Nominatim
import pymongo

# %% [markdown]
# **Funções:**

# %%
def readCSV (path):
    return pd.read_csv(path, sep = ";");

def readXLSX (path):
    return pd.read_excel(path, index_col=None);

def openDataBaseMongoDB ():
    client = pymongo.MongoClient("mongodb://<ADMIN>:<PASSWORD>@criedata-shard-00-00.urzuu.mongodb.net:27017,criedata-shard-00-01.urzuu.mongodb.net:27017,criedata-shard-00-02.urzuu.mongodb.net:27017/<dbname>?ssl=true&replicaSet=atlas-6db9id-shard-0&authSource=admin&retryWrites=true&w=majority");
    db = client.schoolData;
    return db.dataINEPSchools;

def dataframeToJSONConverter (dataframe):
    dataJSON = dataframe.to_json(orient="records")
    return json.loads(dataJSON)

def deletingColumns (columns, dataframe):  
    for column in columns:
        try:
            dataframe.pop(column)
        except:
            continue
    
def JSONstructure (data):    
    dataJSON = {"Média de Alunos por Turma": 
                {
                "Última atualização": data["Ano"],
                "Educação Infantil": 
                    {
                        "Total": data["TotalI"],
                        "Creche": data["Creche"],
                        "Pré-Escola": data["Pré-Escola"]
                    },
                "Ensino Fundamental 8 e 9 anos": 
                    {
                        "Total": data["TotalF"],
                        "Anos Iniciais": data["Anos Iniciais"],
                        "Anos Finais": data["Anos Finais"],
                        "1º Ano": data["1° ano"],
                        "2º Ano": data["2° ano"],
                        "3º Ano": data["3° ano"],
                        "4º Ano": data["4° ano"],
                        "5º Ano": data["5° ano"],
                        "6º Ano": data["6° ano"],
                        "7º Ano": data["7° ano"],
                        "8º Ano": data["8° ano"],
                        "9º Ano": data["9° ano"],
                        "Turmas Multietapa, Multi ou Correção de Fluxo 2": data["Turmas Multietapa, Multi ou Correção de Fluxo 2"]
                    },
                "Ensino Médio": 
                    {
                        "Total": data["TotalM"],
                        "1ª série": data["1ª série"],
                        "2ª série": data["2ª série"],
                        "3ª série": data["3ª série"],
                        "4ª série": data["4ª série"],
                        "Não-Seriado": data["Não-Seriado"]
                    }
        }};

    return dataJSON;

def insertDATABD():
    #collection.insert_many()
    collection.find_one()

# %% [markdown]
# **Conexão com o BD:**

# %%
collection = openDataBaseMongoDB()

# %% [markdown]
# ### ETL: Informações das Escolas

# %%
infoSchools = readCSV(r'C:\Users\mbrug\Desktop\schoolDataCollectionPelotas\Datasets\INEP\InformacoesGeraisDasEscolas.csv');
infoSchools.head()
# Out:
#                             Restrição de Atendimento  \
# 0  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 1                                  ESCOLA PARALISADA
# 2  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 3  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
#
#                        Escola  Código INEP  UF Município Localização  \
# 0  COLEGIO TIRADENTES PELOTAS     43000304  RS   Pelotas      Urbana
# 1       EEI NOSSOS AMIGUINHOS     43001084  RS   Pelotas      Urbana
# 2           EEI CRIANCA AMADA     43001165  RS   Pelotas      Urbana
# 3         EEI MUNDO DO MICKEY     43001173  RS   Pelotas      Urbana
# 4    EEI CHAPEUZINHO VERMELHO     43002145  RS   Pelotas      Urbana
#
#                              Localidade Diferenciada Categoria Administrativa  \
# 0  A escola não está em área de localização difer...                  Pública
# 1                                      Não Informado                  Privada
# 2  A escola não está em área de localização difer...                  Privada
# 3  A escola não está em área de localização difer...                  Privada
# 4  A escola não está em área de localização difer...                  Privada
#
#                                             Endereço       Telefone  \
# 0  AV DUQUE DE CAXIAS 546, 546 FRAGATA. 96030-003...  (53) 32812866
# 1  RUA VOLUNTARIOS DA PATRIA, 1927. CENTRO. 96015...  (53) 30256230
# 2  AVENIDA DOMINGOS JOSE DE ALMEIDA, 1077 AREAL. ...  (53) 30282009
# 3  RUA BALDOMERO TRAPAGA, 132 PORTO. 96075-540 Pe...  (53) 32279908
# 4  RUA BARAO DE SANTA TECLA, 621 CENTRO. 96010-14...  (53) 81265782
#
#   Dependência Administrativa Categoria Escola Privada  \
# 0                   Estadual            Não Informado
# 1                    Privada            Não Informado
# 2                    Privada               Particular
# 3                    Privada               Particular
# 4                    Privada               Particular
#
#   Conveniada Poder Público Regulamentação pelo Conselho de Educação  \
# 0                      Não                                      Sim
# 1                      Não                                      NaN
# 2                      Não                                      Sim
# 3                      Não                                      Sim
# 4                      Não                                      Sim
#
#                                Porte da Escola  \
# 0  Entre 201 e 500 matrículas de escolarização
# 1                                          NaN
# 2   Entre 51 e 200 matrículas de escolarização
# 3           Até 50 matrículas de escolarização
# 4           Até 50 matrículas de escolarização
#
#   Etapas e Modalidade de Ensino Oferecidas Outras Ofertas Educacionais  \
# 0                             Ensino Médio                         NaN
# 1                                      NaN                         NaN
# 2                        Educação Infantil                         NaN
# 3                        Educação Infantil                         NaN
# 4                        Educação Infantil                         NaN
#
#    Latitude  Longitude
# 0 -31.75701  -52.37308
# 1       NaN        NaN
# 2       NaN        NaN
# 3 -31.77139  -52.32994
# 4 -31.76221  -52.34358

# %%
infoSchools.shape
# Out:
# (302, 19)

# %%
infoSchools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Restrição de Atendimento                  302 non-null    object
#  1   Escola                                    302 non-null    object
#  2   Código INEP                               302 non-null    int64
#  3   UF                                        302 non-null    object
#  4   Município                                 302 non-null    object
#  5   Localização                               302 non-null    object
#  6   Localidade Diferenciada                   302 non-null    object
#  7   Categoria Administrativa                  302 non-null    object
#  8   Endereço                                  302 non-null    object
#  9   Telefone                                  292 non-null    object
#  10  Dependência Administrativa                302 non-null    object
#  11  Categoria Escola Privada                  302 non-null    object
#  12  Conveniada Poder Público                  302 non-null    object
#  13  Regulamentação pelo Conselho de Educação  239 non-null    object
#  14  Porte da Escola                           239 non-null    object
#  15  Etapas e Modalidade de Ensino Oferecidas  236 non-null    object
#  16  Outras Ofertas Educacionais               90 non-null     object
#  17  Latitude                                  198 non-null    float64
#  18  Longitude                                 198 non-null    float64
# dtypes: float64(2), int64(1), object(16)
# memory usage: 45.0+ KB

# %%
infoSchools.isnull().sum()
# Out:
# Restrição de Atendimento                      0
# Escola                                        0
# Código INEP                                   0
# UF                                            0
# Município                                     0
# Localização                                   0
# Localidade Diferenciada                       0
# Categoria Administrativa                      0
# Endereço                                      0
# Telefone                                     10
# Dependência Administrativa                    0
# Categoria Escola Privada                      0
# Conveniada Poder Público                      0
# Regulamentação pelo Conselho de Educação     63
# Porte da Escola                              63
# Etapas e Modalidade de Ensino Oferecidas     66
# Outras Ofertas Educacionais                 212
# Latitude                                    104
# Longitude                                   104
# dtype: int64

# %% [markdown]
# **Processo de Geocoding:**

# %%
infoSchools["Endereço"][2]
# Out:
# 'AVENIDA DOMINGOS JOSE DE ALMEIDA, 1077 AREAL. 96085-470 Pelotas - RS.'

# %%
geolocator = Nominatim(user_agent = "ScoolarData")
latitude = []
longitude = []

for local in collectionINEP["Endereço"]:
    try:
        location = geolocator.geocode(local)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except:
        continue

# %% [markdown]
# **Conversão do *dataframe* para json:**

# %%
schoolData = dataframeToJSONConverter (infoSchools)
schoolData[0]
# Out:
# {'Restrição de Atendimento': 'ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATENDIMENTO',
#  'Escola': 'COLEGIO TIRADENTES PELOTAS',
#  'Código INEP': 43000304,
#  'UF': 'RS',
#  'Município': 'Pelotas',
#  'Localização': 'Urbana',
#  'Localidade Diferenciada': 'A escola não está em área de localização diferenciada',
#  'Categoria Administrativa': 'Pública',
#  'Endereço': 'AV DUQUE DE CAXIAS 546, 546 FRAGATA. 96030-003 Pelotas - RS.',
#  'Telefone': '(53) 32812866',
#  'Dependência Administrativa': 'Estadual',
#  'Categoria Escola Privada': 'Não Informado',
#  'Conveniada Poder Público': 'Não',
#  'Regulamentação pelo Conselho de Educação': 'Sim',
#  'Porte da Escola': 'Entre 201 e 500 matrículas de escolarização',
#  'Etapas e Modalidade de Ensino Oferecidas': 'Ensino Médio',
#  'Outras Ofertas Educacionais': None,
#  'Latitude': -31.75701,
#  'Longitude': -52.37308}

# %% [markdown]
# ### ETL: Média de estudates por escola

# %%
studentsAVG_2019 = readXLSX(r'C:\Users\mbrug\Desktop\schoolDataCollectionPelotas\Datasets\INEP\MediaDeAlunosPorTurma.xlsx')

# %%
studentsAVG_2019
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 176381  2019  Centro-Oeste  DF              5300108               Brasília
# 176382  2019  Centro-Oeste  DF              5300108               Brasília
# 176383  2019  Centro-Oeste  DF              5300108               Brasília
# 176384  2019  Centro-Oeste  DF              5300108               Brasília
# 176385  2019  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# 0               11022558     EIEEF HAP BITT TUPARI       Rural
# 1               11024275  CEEJA LUIZ VAZ DE CAMOES      Urbana
# 2               11024291       EMMEF 7 DE SETEMBRO       Rural
# 3               11024372           EMEIEF ANA NERY      Urbana
# 4               11024666      EMEIEF BOA ESPERANCA       Rural
# ...                  ...                       ...         ...
# 176381          53084020       ESC PEQUENO ENCANTO      Urbana
# 176382          53084039              COL ANCHIETA      Urbana
# 176383          53084055                  COL MAPA      Urbana
# 176384          53085000     COBIAN - COL BIANGULO      Urbana
# 176385          53086007         CED VITORIA REGIA      Urbana
#
#        Dependência Administrativa TotalI  ... 7° ano 8° ano 9° ano  \
# 0                        Estadual     --  ...     --     --     --
# 1                        Estadual     --  ...     --     --     --
# 2                       Municipal     --  ...     --     --     --
# 3                       Municipal     10  ...      7     15      8
# 4                       Municipal     16  ...     20     26     18
# ...                           ...    ...  ...    ...    ...    ...
# 176381                    Privada   16.2  ...     --     --     --
# 176382                    Privada   15.8  ...   23.5   22.5   17.5
# 176383                    Privada     --  ...   21.3   29.5   25.5
# 176384                    Privada   16.9  ...     --     --     --
# 176385                    Privada     --  ...     14     20     31
#
#        Turmas Multietapa, Multi ou Correção de Fluxo 2 TotalM 1ª série  \
# 0                                                    7     --       --
# 1                                                   --     --       --
# 2                                                   10     --       --
# 3                                                 23.5     --       --
# 4                                                   --     --       --
# ...                                                ...    ...      ...
# 176381                                              --     --       --
# 176382                                              --    9.3       13
# 176383                                              --   28.7       32
# 176384                                              --     --       --
# 176385                                              --   32.3       39
#
#        2ª série 3ª série 4ª série Não-Seriado
# 0            --       --       --          --
# 1            --       --       --          --
# 2            --       --       --          --
# 3            --       --       --          --
# 4            --       --       --          --
# ...         ...      ...      ...         ...
# 176381       --       --       --          --
# 176382       11        4       --          --
# 176383       24       30       --          --
# 176384       --       --       --          --
# 176385     23.5       43       --          --
#
# [176386 rows x 31 columns]

# %%
filter = studentsAVG_2019["Nome do Município"] == "Pelotas"

filterPelotas = studentsAVG_2019.where(filter)
studentsAVG_2019Pelotas = filterPelotas.dropna()
studentsAVG_2019Pelotas.reset_index(drop=True, inplace=True)
studentsAVG_2019Pelotas.head()
# Out:
#       Ano Região  UF  Código do Município Nome do Município  Código da Escola  \
# 0  2019.0    Sul  RS            4314407.0           Pelotas        43000304.0
# 1  2019.0    Sul  RS            4314407.0           Pelotas        43001165.0
# 2  2019.0    Sul  RS            4314407.0           Pelotas        43001173.0
# 3  2019.0    Sul  RS            4314407.0           Pelotas        43002145.0
# 4  2019.0    Sul  RS            4314407.0           Pelotas        43003222.0
#
#                Nome da Escola Localização Dependência Administrativa TotalI  \
# 0  COLEGIO TIRADENTES PELOTAS      Urbana                   Estadual     --
# 1           EEI CRIANCA AMADA      Urbana                    Privada     14
# 2         EEI MUNDO DO MICKEY      Urbana                    Privada      3
# 3    EEI CHAPEUZINHO VERMELHO      Urbana                    Privada    3.5
# 4             EEF TRES VENDAS      Urbana                    Privada     --
#
#    ... 7° ano 8° ano 9° ano Turmas Multietapa, Multi ou Correção de Fluxo 2  \
# 0  ...     --     --     --                                              --
# 1  ...     --     --     --                                              --
# 2  ...     --     --     --                                              --
# 3  ...     --     --     --                                              --
# 4  ...   30.5     37     --                                              --
#
#   TotalM 1ª série 2ª série 3ª série 4ª série Não-Seriado
# 0   26.6       25       26       30       --          --
# 1     --       --       --       --       --          --
# 2     --       --       --       --       --          --
# 3     --       --       --       --       --          --
# 4     --       --       --       --       --          --
#
# [5 rows x 31 columns]

# %%
columns = ["Região", "UF", "Código do Município", "Nome do Município", "Nome da Escola", "Localização", "Dependência Administrativa"];

deletingColumns(columns, studentsAVG_2019Pelotas)
studentsAVG_2019Pelotas.reset_index(drop=True, inplace = True)

# %%
studentsAVG_2019Pelotas[""]
# Out:
#       Ano  Código da Escola TotalI Creche Pré-Escola TotalF Anos Iniciais  \
# 0  2019.0        43000304.0     --     --         --     --            --
# 1  2019.0        43001165.0     14   13.6         15     --            --
# 2  2019.0        43001173.0      3      6        1.5     --            --
# 3  2019.0        43002145.0    3.5    4.3        2.7     --            --
# 4  2019.0        43003222.0     --     --         --   29.4          27.3
#
#   Anos Finais 1° ano 2° ano  ... 7° ano 8° ano 9° ano  \
# 0          --     --     --  ...     --     --     --
# 1          --     --     --  ...     --     --     --
# 2          --     --     --  ...     --     --     --
# 3          --     --     --  ...     --     --     --
# 4        34.7   26.7   27.7  ...   30.5     37     --
#
#   Turmas Multietapa, Multi ou Correção de Fluxo 2 TotalM 1ª série 2ª série  \
# 0                                              --   26.6       25       26
# 1                                              --     --       --       --
# 2                                              --     --       --       --
# 3                                              --     --       --       --
# 4                                              --     --       --       --
#
#   3ª série 4ª série Não-Seriado
# 0       30       --          --
# 1       --       --          --
# 2       --       --          --
# 3       --       --          --
# 4       --       --          --
#
# [5 rows x 24 columns]

# %% [markdown]
# **Inserindo no BD:**

# %%
count = 0;
for index, row in studentsAVG_2019Pelotas.iterrows():
    teste1 = JSONstructure(row);
    
    collection.update_one({"Código INEP": row["Código da Escola"]}, {"$set": teste1})

# %%
collection.find_one({"Código INEP": 43000304})
# Out:
# {'_id': ObjectId('5f22117d86818b0338731eb4'),
#  'Restrição de Atendimento': 'ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATENDIMENTO',
#  'Escola': 'COLEGIO TIRADENTES PELOTAS',
#  'Código INEP': 43000304,
#  'UF': 'RS',
#  'Município': 'Pelotas',
#  'Localização': 'Urbana',
#  'Localidade Diferenciada': 'A escola não está em área de localização diferenciada',
#  'Categoria Administrativa': 'Pública',
#  'Endereço': 'AV DUQUE DE CAXIAS 546, 546 FRAGATA. 96030-003 Pelotas - RS.',
#  'Telefone': '(53) 32812866',
#  'Dependência Administrativa': 'Estadual',
#  'Categoria Escola Privada': 'Não Informado',
#  'Conveniada Poder Público': 'Não',
#  'Regulamentação pelo Conselho de Educação': 'Sim',
#  'Porte da Escola': 'Entre 201 e 500 matrículas de escolarização',
#  'Etapas e Modalidade de Ensino Oferecidas': 'Ensino Médio',
#  'Outras Ofertas Educacionais': None,
#  'Latitude': -31.75701,
#  'Longitude': -52.37308,
#  'Média de Alunos por Turma': {'Última atualização': 2019.0,
#   'Educação Infantil': {'Total': '--', 'Creche': '--', 'Pré-Escola': '--'},
#   'Ensino Fundamental 8 e 9 anos': {'Total': '--',
#    'Anos Iniciais': '--',
#    'Anos Finais': '--',
#    '1º Ano': '--',
#    '2º Ano': '--',
#    '3º Ano': '--',
#    '4º Ano': '--',
#    '5º Ano': '--',
#    '6º Ano': '--',
#    '7º Ano': '--',
#    '8º Ano': '--',
#    '9º Ano': '--',
#    'Turmas Multietapa, Multi ou Correção de Fluxo 2': '--'},
#   'Ensino Médio': {'Total': 26.6,
#    '1ª série': 25,
#    '2ª série': 26,
#    '3ª série': 30,
#    '4ª série': '--',
#    'Não-Seriado': '--'}}}
